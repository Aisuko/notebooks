# %%
# !git clone https://github.com/spcl/QuaRot.git && cd QuaRot && pip install -e .

# %%
# !python /kaggle/working/QuaRot/fake_quant/main.py --model meta-llama/Llama-2-7b-hf  --rotate --a_bits 4 --v_bits 4 --k_bits 4 --w_bits 4 --w_clip
