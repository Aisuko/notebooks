# %% [markdown]
# <a href="https://www.kaggle.com/code/aisuko/text2text-with-ctransformers?scriptVersionId=164529302" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # CTransformers
#
# Python bindings for the Transformer models implemented in C/C++ using GGML library. License it MIT.
#
#
# # Check if the CPU with support for AVX or AVX2

# %%
# !grep avx /proc/cpuinfo
# Out:
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_good nopl nonstop_tsc cpuid extd_apicid tsc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw topoext ssbd ibrs ibpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 smep bmi2 rdseed adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_save umip rdpid
# ...

# %%
# !grep avx2 /proc/cpuinfo
# Out:
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_good nopl nonstop_tsc cpuid extd_apicid tsc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw topoext ssbd ibrs ibpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 smep bmi2 rdseed adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_save umip rdpid
# ...

# %% [markdown]
# # Check the list of avaliable versions

# %%
# !python -m pip index versions ctransformers --index-url=https://jllllll.github.io/ctransformers-cuBLAS-wheels/AVX2/cu117
# Out:
# WARNING: pip index is currently an experimental command. It may be removed/changed in a future release without prior warning.
# ctransformers (0.2.27+cu117)
# Available versions: 0.2.27+cu117, 0.2.26+cu117, 0.2.25+cu117, 0.2.24+cu117, 0.2.23+cu117, 0.2.22+cu117, 0.2.21+cu117, 0.2.20+cu117, 0.2.19+cu117, 0.2.18+cu117, 0.2.17+cu117, 0.2.16+cu117, 0.2.15+cu117, 0.2.14+cu117, 0.2.13+cu117

# %%
# !python -m pip install ctransformers==0.2.27 --prefer-binary --extra-index-url=https://jllllll.github.io/ctransformers-cuBLAS-wheels/AVX2/cu117
# Out:
# Looking in indexes: https://pypi.org/simple, https://jllllll.github.io/ctransformers-cuBLAS-wheels/AVX2/cu117
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 78.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Constructing configuration

# %%
from ctransformers import Config, AutoConfig

config =Config(
    top_k= 40,
    top_p = 0.95,
    temperature = 0.8,
    repetition_penalty = 1.1,
    last_n_tokens= 64,
    seed= -1,
    batch_size = 8,
    threads = -1,
    max_new_tokens = 256,
    stop = None,
    stream = False,
    reset = True,
    context_length = -1,
    gpu_layers = 0,
    mmap = True,
    mlock = False
)

auto_config=AutoConfig(config=config, model_type="gpt2")

# %% [markdown]
# # Loading models from Hugging Face Hub directly

# %%
from ctransformers import AutoModelForCausalLM

llm = AutoModelForCausalLM.from_pretrained("marella/gpt-2-ggml", model_file="ggml-model.bin",config=auto_config)
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
print(llm('The papers are realated to'))
# Out:
#  be able to do so, and I can see that it will allow us a better understanding of what's going on.
# There is an issue with the use in some places where you might want to change something as well; there has been very little work done for this sort 'citizen science' aspect over at Facebook which does not really give people much freedom or accountability when they go and ask questions, so it was nice having someone on hand.
# But what's going into that is just being able put things together with a group of individuals who have had to be very good communicators for their work because you've got some real expertise about this subject at Facebook in the past - or if I may say they were even there before we did, which would explain why so many people came back.
# ...
