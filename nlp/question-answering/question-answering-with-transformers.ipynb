# %% [markdown]
# # Overview
#
# Let's use Huggingface Transformers for Question and answering pipeline. We want to implement an evaluation machanism for RAG framework and the first idea comes out is using question-answering  and NER pipeline.

# %%
# !pip install -U -q transformers==4.39.3
# !pip install -U -q accelerate==0.28.0

# %%
import torch
from transformers import pipeline

# we use default model is distilbert
pipe=pipeline(task='question-answering',
              model="distilbert/distilbert-base-cased-distilled-squad", 
              device='cuda', 
              torch_dtype=torch.bfloat16)
pipe.device
# Out:
# 2024-04-23 00:49:29.427484: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-23 00:49:29.427610: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-23 00:49:29.559467: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# device(type='cuda')

# %%
context='Melbourne is the one of the most lievable cities in Earth, however, many incidents were happend these days'
question='Does Melboune is a liveable city?'

# https://github.com/huggingface/transformers/blob/v4.40.0/src/transformers/pipelines/question_answering.py#L224
pipe(context=context, question=question)
# Out:
# {'score': 0.23802000284194946, 'start': 0, 'end': 9, 'answer': 'Melbourne'}
