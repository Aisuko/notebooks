# %%
# !pip install transformers==4.39.3
# Out:
# Collecting transformers==4.39.3
#   Downloading transformers-4.39.3-py3-none-any.whl.metadata (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers==4.39.3) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/conda/lib/python3.10/site-packages (from transformers==4.39.3) (0.21.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.39.3) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.39.3) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.39.3) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.39.3) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers==4.39.3) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers==4.39.3) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.39.3) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers==4.39.3) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.3) (2024.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.3) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers==4.39.3) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.39.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.39.3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.39.3) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.39.3) (2024.2.2)
# Downloading transformers-4.39.3-py3-none-any.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 72.0 MB/s eta 0:00:00:00:010:01
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# Successfully installed transformers-4.39.3

# %% [markdown]
# # Downloading specific file

# %%
from huggingface_hub import hf_hub_download

model_id = "microsoft/Mistral-7B-v0.1-onnx"
revision = "main" # or a specific commit SHA
filename = "README.md" 

hf_hub_download(repo_id=model_id, filename=filename, revision=revision)
# Out:
# LICENSE:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# '/root/.cache/huggingface/hub/models--microsoft--phi-2/snapshots/b10c3eba545ad279e7208ee3a5d644566f001670/LICENSE'

# %% [markdown]
# # Downloading entire model repo
#
# snapshot_download() downloads an entire repository at a given revision. It uses internally hf_hub_download() which means all downloaded files are also cached on your local disk. Downloads are made concurrently to speed-up the process.

# %%
from huggingface_hub import snapshot_download

snapshot_download(repo_id="microsoft/phi-2",
                  repo_type="model",
                  revision="main",
                  cache_dir="phi-2",
                  local_dir="phi-2"
                 )
# Out:
# Fetching 19 files:   0%|          | 0/19 [00:00<?, ?it/s]
# CODE_OF_CONDUCT.md:   0%|          | 0.00/444 [00:00<?, ?B/s]
# SECURITY.md:   0%|          | 0.00/2.66k [00:00<?, ?B/s]
# NOTICE.md:   0%|          | 0.00/1.77k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/863 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/8.04k [00:00<?, ?B/s]

# %%
# !ls phi-2

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

# https://github.com/huggingface/transformers/blob/09f9f566de83eef1f13ee83b5a1bbeebde5c80c1/src/transformers/configuration_utils.py#L49
pipe = pipeline("text-generation",
                name_or_path="phi-2",
                device_map="auto",
                trust_remote_code=True)
pipe
